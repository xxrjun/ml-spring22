# %% [markdown]
# ![](https://i.imgur.com/3twMqGw.png)
#
# # 作業2 : 股票預測
#
# ## **請挑選一家公司來做預測**
#
# 資料集: [鉅亨網](https://www.cnyes.com/)
#
# > **資料集說明**
#
# 別人恐懼我貪婪，一張不賣奇蹟來。
#
# >**作業說明**
#
# **第一步驟**: 左上角 檔案->在雲端硬碟建立副本。
#
# **第二步驟**: 右上角 共用->取得連結->任何知道這個連結的人都能編輯
#
# **第三步驟**: 左上角 執行階段->更變執行類型->GPU。 可以加快模型速度
#
# **第四步驟**: 檔案名稱，請填寫你的學號，把副本上下引號刪掉
#
# 請 **隨意修改** 這個colab的程式來完成訓練RNN模型。**不必一定要照著todo提示走。**
# 繳交時記得改檔案標題的學號。
#
# 這次作業的重點在於RNN的維度問題。
#
# > **作業限制**
#
# 1. 不要動資料集、不要在訓練時偷看test data
# 2. 模型請手刻、手疊，**不要用Transfer Learning**，你可以手刻transformer。
# 3. **不要抄襲**
#
# > **作業繳交**
#
# 1. 完成訓練後保存output結果，更改**檔名學號**，左上角 檔案->下載 成ipynb檔。
# 2. 交一個**pdf**檔，裡面需要附上**你的作業colab連結(設為可編輯、所有人觀看)**、姓名學號年級、過程和執行結果的截圖，並說明你程式撰寫的過程、本次作業心得(字數不限)。
# 3. 上述三個檔案繳交至ee-class。(Text Generation、Stock、PDF)
#
# > **繳交期限**
#
# 1. 電子商務技術(IM5002): 期限至2021/5/16(一) 23:59分
# 2. 人工智慧與機器學習(IM3078): 期限至2022/5/16(一) 23:59分
# 3. 電子商務智慧技術(IMA0200): 期限至2022/5/14(六) 23:59分
#
# > **算分標準**
#
# Text Generation(20) + Stock RNN(30) + Predict function(20分) + 30分文件
# 1.  [Text Generation](https://colab.research.google.com/drive/1bMkAUaiivMaOr8Sd1Ui-KJeoFImEVUqA?usp=sharing) 換個其他資料集來訓練，完成就20分
# 2. Stock RNN完成模型就30分
# 3. predit function有寫出來就20分(第七段)
# 4. 30分是文件分數
# 5. 記得把以上評分標準截圖、並與你的心得一起貼上pdf
#
# 有問題再來信助教: chiachentu@g.ncu.edu.tw(凃家甄)、lufor129@g.ncu.edu.tw(黃智輝)

# %%
# 太多人同時存取可能會報cannot retrieve file error
# 點擊you may still be able to access 下面那個連結再自行上傳檔案即可

import os

if(os.path.isfile("./train.csv") == False or os.path.isfile("./test.csv") == False):
  # !wget -O train.csv "http://140.115.82.54/NN/Recurrent/train.csv"
  # !wget -O test.csv "http://140.115.82.54/NN/Recurrent/test.csv"
  # !gdown --id 1iK40K9oXsmhJGs7XSn7q3I1XuPtsZiSj --output "./train.csv"
  # !gdown --id 1kZIgeeTnzQf6GJGJuqOe9BgkFa8qb7hJ --output "./test.csv"

# %% [markdown]
# ## 1. 讀入Package

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import random
import datetime
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 2. 取得資料集

# %%
train_df = pd.read_csv("./train.csv")
train_df = train_df[::-1]
print("company : ",train_df["company"].unique())
train_df.head()
# Out:
# company :  [2317 2454 2330]
#       company      date  price
# 6687     2317  2012/1/2   81.4
# 6686     2317  2012/1/3   82.7
# 6685     2317  2012/1/4   83.2
# 6684     2317  2012/1/5   83.2
# 6683     2317  2012/1/6   83.9

# %%
test_df = pd.read_csv("./test.csv")
test_df = test_df[::-1]
print("test data shape : ",test_df.shape)
test_df.head()
# Out:
# test data shape :  (117, 3)
#      company      date  price
# 116     2317  2021/2/1  113.0
# 115     2317  2021/2/2  116.5
# 114     2317  2021/2/3  116.5
# 113     2317  2021/2/4  114.0
# 112     2317  2021/2/5  113.5

# %%
####################################
#                 #
# 自己決定三家公司哪家公司(填數字)#
# 挑選一家公司來做訓練、預測   #
#                 #
#                 #
####################################
companys = {"2330":"TSMC","2454":"MEDIATEK","2317":"FOXCONN"}
company_id = 2454

# %%
company = train_df[train_df["company"] == company_id]
company.index = company["date"]
company.head()
# Out:
#           company      date  price
# date
# 2012/1/2     2454  2012/1/2  273.0
# 2012/1/3     2454  2012/1/3  280.0
# 2012/1/4     2454  2012/1/4  280.5
# 2012/1/5     2454  2012/1/5  282.0
# 2012/1/6     2454  2012/1/6  278.5

# %%
def include_last_iter(start,end,step):
  i = start
  while i < end:
      yield i
      i += step
  yield end-1

# %%
plt.figure(figsize=(16, 8))
plt.subplots_adjust(hspace=0.5)
for index,c in enumerate(companys):
  plt.subplot(2,2,index+1)
  company_df = train_df[train_df["company"] == int(c)]
  plt.plot(company_df["date"],company_df["price"])
  plt.xticks(list(include_last_iter(0,company_df.shape[0],250)),rotation=30)
  plt.title(companys[c])
  plt.xlabel("Date")
  plt.ylabel("price")
    
plt.show()

# %% [markdown]
# ## 3. 資料前處理

# %%
# 切分training data & validation data
total_len = company.shape[0]
training_len = 2100
validation_data = total_len - training_len

print("總共有 : ",total_len,"筆")
print("訓練用 : (前)",training_len,"筆")
print("驗證用 : (後)",validation_data,"筆")
# Out:
# 總共有 :  2231 筆
# 訓練用 : (前) 2100 筆
# 驗證用 : (後) 131 筆

# %%
# 自己做 MinMax Transformer 前處理 
class MinMaxTransformer:
  def __init__(self):
    self.min = None
    self.max = None
    self.distance = None

  def fit(self,data):
    self.min = min(data)
    self.max = max(data)
    self.distance = self.max - self.min
    out = [(d-self.min)/self.distance for d in data]
    return out

  def recover(self,data):
    out = [d*self.distance+self.min for d in data]
    return out

  def transform(self,data):
    out = [(d-self.min)/self.distance for d in data]
    return out

  def transform_one(self,data):
    return (data-self.min)/self.distance

# %%
train_prices = company["price"].values

scalar = MinMaxTransformer()
scalar_data = scalar.fit(train_prices)

# %%
# 做正規化
print("origin data : ",train_prices[:5])
print("transform data : ",scalar_data[:5])
print("recover data : ",scalar.recover(scalar_data[:5]))
# Out:
# origin data :  [273.  280.  280.5 282.  278.5]
# transform data :  [0.1091644204851752, 0.11859838274932614, 0.1192722371967655, 0.12129380053908356, 0.11657681940700809]
# recover data :  [273.0, 280.0, 280.5, 282.0, 278.5]

# %%
# 切分資料集
training_data = scalar_data[:training_len]
validation_data = scalar_data[training_len:]

# %%
# todo 決定Seq長度
seq_len = 15

def split_input_target(seq):
  input_txt = tf.expand_dims(seq[:-1],-1)
  target_txt = tf.expand_dims(seq[1:],-1)
  return input_txt,target_txt

# %%
def make_ds(data):
  data_slice = tf.data.Dataset.from_tensor_slices(data)
  data_sequence = data_slice.batch(seq_len+1,drop_remainder=True)

  dataset = data_sequence.map(split_input_target)
  return dataset

# %%
# 製作資料集
train_ds = make_ds(training_data)
val_ds = make_ds(validation_data)

# print(train_ds)

# print(val_ds)

for input_example,target_example in train_ds.take(1):
  print("Input :", scalar.recover(input_example.numpy()))
  print("Target:", scalar.recover(target_example.numpy()))
  print("-"*50)
  print("Input :", input_example.numpy())
  print("Target:", target_example.numpy())

# x_train = []
# y_train = []
# x_test = []
# y_test = []

# # Training Set
# for input_example, target_example in train_ds:
#   input = input_example.numpy()
#   target = target_example.numpy()

#   x_train.append(input)
#   y_train.append(target)

# # Validation
# for input_example, target_example in val_ds:
#   input = input_example.numpy()
#   target = target_example.numpy()

#   x_test.append(input)
#   y_test.append(target)

# x_train = np.array(x_train)
# x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))


# y_train = np.array(y_train)
# y_train = np.reshape(y_train, (y_train.shape[0], y_train.shape[1], 1))

# x_test = np.array(x_test)
# x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# y_test = np.array(y_test)
# y_test = np.reshape(y_test, (y_test.shape[0], y_test.shape[1], 1))
# Out:
# Input : [array([273.]), array([280.]), array([280.5]), array([282.]), array([278.5]), array([267.]), array([270.]), array([274.5]), array([272.]), array([272.]), array([260.]), array([263.]), array([263.]), array([279.5]), array([282.5])]
# Target: [array([280.]), array([280.5]), array([282.]), array([278.5]), array([267.]), array([270.]), array([274.5]), array([272.]), array([272.]), array([260.]), array([263.]), array([263.]), array([279.5]), array([282.5]), array([288.])]
# --------------------------------------------------
# Input : [[0.10916442]
#  [0.11859838]
#  [0.11927224]
#  [0.1212938 ]
#  [0.11657682]
#  [0.10107817]
#  [0.10512129]
#  [0.11118598]
#  [0.10781671]
#  [0.10781671]
#  [0.0916442 ]
#  [0.09568733]
#  [0.09568733]
#  [0.11792453]
#  [0.12196765]]
# Target: [[0.11859838]
#  [0.11927224]
#  [0.1212938 ]
#  [0.11657682]
#  [0.10107817]
#  [0.10512129]
#  [0.11118598]
#  [0.10781671]
#  [0.10781671]
#  [0.0916442 ]
#  [0.09568733]
#  [0.09568733]
#  [0.11792453]
#  [0.12196765]
#  [0.12938005]]

# %%
# Batch size
# todo 決定Batch大小
BATCH_SIZE = 32

BUFFER_SIZE = training_len

train_ds = train_ds.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
val_ds = val_ds.batch(BATCH_SIZE)

# %% [markdown]
# ## 4. 建立模型
#
# 提示: Output是一個數值，所以Model output維度為1。
#
# * 輸入維度應為: (batch,seq_len,1)
#
# * 輸出維度應為: (batch,seq_len,1)
#
# **最後一層Dense不要加上任何activation function。**

# %%
# todo
input_shape = (seq_len, 1)
output_shape = [BATCH_SIZE, seq_len, 1]

lstm_units = [4096, 2048, 1024, 512]
d = 0.2

keras.backend.clear_session()

# Build model
model = tf.keras.Sequential(
    [
      layers.LSTM(units=lstm_units[0], input_shape=input_shape,return_sequences=True),      
      layers.Dropout(d),
      
      layers.LSTM(units=lstm_units[1], return_sequences=True), 
      layers.Dropout(d),
         
      layers.LSTM(units=lstm_units[2], return_sequences=True),
      layers.Dropout(d),
     
      # layers.LSTM(units=lstm_units[3], return_sequences=True),
      # layers.Dropout(d),
     
      layers.Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 15, 4096)          67141632
#
#  dropout (Dropout)           (None, 15, 4096)          0
#
#  lstm_1 (LSTM)               (None, 15, 2048)          50339840
#
#  dropout_1 (Dropout)         (None, 15, 2048)          0
#
#  lstm_2 (LSTM)               (None, 15, 1024)          12587008
#
#  dropout_2 (Dropout)         (None, 15, 1024)          0
#
#  dense (Dense)               (None, 15, 1)             1025
#
# =================================================================
# Total params: 130,069,505
# Trainable params: 130,069,505
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 5. 制定訓練計畫並訓練
#
# 我們做數字相關預測，可以考慮用Mean_Squared_Error
#
# 公式:
# $$MSE = \frac{1}{n} \sum_{i=1}^N({\gamma-\hat{\gamma}})^2$$
#
#
# 提示:
# 不用管公式在幹嘛，compile帶入mean_squared_error。

# %%
epochs = 500

# adam = keras.optimizers.Adam(decay=0.2)
model.compile(loss='mse', optimizer='adam')

history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    epochs=epochs,
    validation_data=val_ds,
    # validation_split=0.1,
    # shuffle=True,
    # verbose=1
)
# Out:
# Epoch 1/500
# 5/5 [==============================] - 7s 389ms/step - loss: 0.0111 - val_loss: 0.0658
# Epoch 2/500
# 5/5 [==============================] - 1s 169ms/step - loss: 0.0029 - val_loss: 0.0487
# Epoch 3/500
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0020 - val_loss: 0.0104
# Epoch 4/500
# 5/5 [==============================] - 1s 168ms/step - loss: 0.0012 - val_loss: 0.0235
# Epoch 5/500
# 5/5 [==============================] - 1s 167ms/step - loss: 0.0014 - val_loss: 0.0048
# Epoch 6/500
# 5/5 [==============================] - 1s 169ms/step - loss: 7.8829e-04 - val_loss: 0.0157
# Epoch 7/500
# 5/5 [==============================] - 1s 168ms/step - loss: 7.6548e-04 - val_loss: 0.0094
# Epoch 8/500
# 5/5 [==============================] - 1s 168ms/step - loss: 6.1397e-04 - val_loss: 0.0030
# Epoch 9/500
# 5/5 [==============================] - 1s 168ms/step - loss: 4.0314e-04 - val_loss: 0.0014
# Epoch 10/500
# 5/5 [==============================] - 1s 168ms/step - loss: 2.5933e-04 - val_loss: 0.0019
# Epoch 11/500
# 5/5 [==============================] - 1s 170ms/step - loss: 2.6156e-04 - val_loss: 7.4886e-04
# Epoch 12/500
# 5/5 [==============================] - 1s 170ms/step - loss: 2.2574e-04 - val_loss: 9.2643e-04
# Epoch 13/500
# 5/5 [==============================] - 1s 169ms/step - loss: 2.1924e-04 - val_loss: 0.0054
# Epoch 14/500
# 5/5 [==============================] - 1s 168ms/step - loss: 4.5024e-04 - val_loss: 0.0047
# Epoch 15/500
# 5/5 [==============================] - 1s 171ms/step - loss: 4.6557e-04 - val_loss: 0.0027
# Epoch 16/500
# 5/5 [==============================] - 1s 169ms/step - loss: 3.1572e-04 - val_loss: 9.3780e-04
# Epoch 17/500
# 5/5 [==============================] - 1s 170ms/step - loss: 1.8857e-04 - val_loss: 0.0016
# Epoch 18/500
# 5/5 [==============================] - 1s 174ms/step - loss: 1.7091e-04 - val_loss: 7.8401e-04
# Epoch 19/500
# 5/5 [==============================] - 1s 176ms/step - loss: 1
500
# 5/5 [==============================] - 1s 176ms/step - loss: 1.4530e-04 - val_loss: 6.7478e-04
# Epoch 184/500
# 5/5 [==============================] - 1s 180ms/step - loss: 1.3378e-04 - val_loss: 7.4995e-04
# Epoch 185/500
# 5/5 [==============================] - 1s 176ms/step - loss: 1.5763e-04 - val_loss: 6.2646e-04
# Epoch 186/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.8293e-04 - val_loss: 0.0046
# Epoch 187/500
# 5/5 [==============================] - 1s 178ms/step - loss: 3.2008e-04 - val_loss: 0.0044
# Epoch 188/500
# 5/5 [==============================] - 1s 178ms/step - loss: 3.7775e-04 - val_loss: 9.9755e-04
# Epoch 189/500
# 5/5 [==============================] - 1s 176ms/step - loss: 3.2543e-04 - val_loss: 0.0015
# Epoch 190/500
# 5/5 [==============================] - 1s 176ms/step - loss: 2.0770e-04 - val_loss: 6.9819e-04
# Epoch 191/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.0695e-04 - val_loss: 0.0013
# Epoch 192/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.7319e-04 - val_loss: 0.0010
# Epoch 193/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.6868e-04 - val_loss: 0.0011
# Epoch 194/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.6979e-04 - val_loss: 8.9423e-04
# Epoch 195/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.5998e-04 - val_loss: 0.0040
# Epoch 196/500
# 5/5 [==============================] - 1s 179ms/step - loss: 2.8356e-04 - val_loss: 0.0017
# Epoch 197/500
# 5/5 [==============================] - 1s 178ms/step - loss: 3.4369e-04 - val_loss: 0.0048
# Epoch 198/500
# 5/5 [==============================] - 1s 176ms/step - loss: 2.6468e-04 - val_loss: 0.0033
# Epoch 199/500
# 5/5 [==============================] - 1s 176ms/step - loss: 2.4087e-04 - val_loss: 6.4929e-04
# Epoch 200/500
# 5/5 [==============================] - 1s 180ms/step - loss: 2.0670e-04 - val_loss: 0.0021
# Epoch 201/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.0280e-04 - val_loss: 0.0011
# Epoch 202/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.7116e-04 - val_loss: 6.2182e-04
# Epoch 203/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.6768e-04 - val_loss: 0.0057
# Epoch 204/500
# 5/5 [==============================] - 1s 176ms/step - loss: 2.2702e-04 - val_loss: 0.0014
# Epoch 205/500
# 5/5 [==============================] - 1s 180ms/step - loss: 2.0271e-04 - val_loss: 5.9748e-04
# Epoch 206/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.5161e-04 - val_loss: 0.0015
# Epoch 207/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.6961e-04 - val_loss: 7.8138e-04
# Epoch 208/500
# 5/5 [==============================] - 1s 180ms/step - loss: 1.5475e-04 - val_loss: 0.0010
# Epoch 209/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.5527e-04 - val_loss: 5.9100e-04
# Epoch 210/500
# 5/5 [==============================] - 1s 176ms/step - loss: 1.9234e-04 - val_loss: 0.0087
# Epoch 211/500
# 5/5 [==============================] - 1s 179ms/step - loss: 3.7213e-04 - val_loss: 0.0062
# Epoch 212/500
# 5/5 [==============================] - 1s 178ms/step - loss: 3.1859e-04 - val_loss: 0.0012
# Epoch 213/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.2059e-04 - val_loss: 8.4940e-04
# Epoch 214/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.6390e-04 - val_loss: 8.0755e-04
# Epoch 215/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.7534e-04 - val_loss: 6.5591e-04
# Epoch 216/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.5282e-04 - val_loss: 8.8985e-04
# Epoch 217/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.3661e-04 - val_loss: 0.0016
# Epoch 218/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.3700e-04 - val_loss: 7.3297e-04
# Epoch 219/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.2316e-04 - val_loss: 7.8250e-04
# Epoch 220/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.4837e-04 - val_loss: 7.4256e-04
# Epoch 221/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.3941e-04 - val_loss: 8.0950e-04
# Epoch 222/500
# 5/5 [==============================] - 1s 176ms/step - loss: 1.6945e-04 - val_loss: 6.1767e-04
# Epoch 223/500
# 5/5 [==============================] - 1s 175ms/step - loss: 1.9033e-04 - val_loss: 0.0102
# Epoch 224/500
# 5/5 [==============================] - 1s 179ms/step - loss: 5.2621e-04 - val_loss: 0.0017
# Epoch 225/500
# 5/5 [==============================] - 1s 177ms/step - loss: 2.6939e-04 - val_loss: 0.0024
# Epoch 226/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.7594e-04 - val_loss: 0.0048
# Epoch 227/500
# 5/5 [==============================] - 1s 176ms/step - loss: 2.5953e-04 - val_loss: 0.0072
# Epoch 228/500
# 5/5 [==============================] - 1s 179ms/step - loss: 2.5938e-04 - val_loss: 0.0030
# Epoch 229/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.1244e-04 - val_loss: 0.0018
# Epoch 230/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.7771e-04 - val_loss: 0.0012
# Epoch 231/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.5745e-04 - val_loss: 0.0025
# Epoch 232/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.7884e-04 - val_loss: 0.0018
# Epoch 233/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.5970e-04 - val_loss: 0.0019
# Epoch 234/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.6036e-04 - val_loss: 6.3022e-04
# Epoch 235/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.4782e-04 - val_loss: 9.1743e-04
# Epoch 236/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.3983e-04 - val_loss: 0.0021
# Epoch 237/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.5104e-04 - val_loss: 7.3046e-04
# Epoch 238/500
# 5/5 [==============================] - 1s 180ms/step - loss: 1.3546e-04 - val_loss: 6.4776e-04
# Epoch 239/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.2929e-04 - val_loss: 5.9666e-04
# Epoch 240/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.3452e-04 - val_loss: 0.0011
# Epoch 241/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.0714e-04 - val_loss: 0.0019
# Epoch 242/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.4009e-04 - val_loss: 6.9682e-04
# Epoch 243/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.2671e-04 - val_loss: 7.0987e-04
# Epoch 244/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.3200e-04 - val_loss: 7.9379e-04
# Epoch 245/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.2892e-04 - val_loss: 0.0017
# Epoch 246/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.3494e-04 - val_loss: 9.0726e-04
# Epoch 247/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.3423e-04 - val_loss: 6.4571e-04
# Epoch 248/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.4955e-04 - val_loss: 7.7708e-04
# Epoch 249/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.6952e-04 - val_loss: 0.0011
# Epoch 250/500
# 5/5 [==============================] - 1s 180ms/step - loss: 1.5777e-04 - val_loss: 0.0042
# Epoch 251/500
# 5/5 [==============================] - 1s 177ms/step - loss: 2.8947e-04 - val_loss: 0.0031
# Epoch 252/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.8011e-04 - val_loss: 8.5022e-04
# Epoch 253/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.5534e-04 - val_loss: 8.9138e-04
# Epoch 254/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.4650e-04 - val_loss: 8.3309e-04
# Epoch 255/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.3081e-04 - val_loss: 0.0010
# Epoch 256/500
# 5/5 [==============================] - 1s 180ms/step - loss: 1.3221e-04 - val_loss: 0.0014
# Epoch 257/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.5774e-04 - val_loss: 0.0024
# Epoch 258/500
# 5/5 [==============================] - 1s 176ms/step - loss: 1.7973e-04 - val_loss: 7.3264e-04
# Epoch 259/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.9104e-04 - val_loss: 8.5539e-04
# Epoch 260/500
# 5/5 [==============================] - 1s 176ms/step - loss: 1.3333e-04 - val_loss: 0.0017
# Epoch 261/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.3786e-04 - val_loss: 6.0049e-04
# Epoch 262/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.4661e-04 - val_loss: 0.0071
# Epoch 263/500
# 5/5 [==============================] - 1s 177ms/step - loss: 4.2242e-04 - val_loss: 0.0017
# Epoch 264/500
# 5/5 [==============================] - 1s 178ms/step - loss: 5.2269e-04 - val_loss: 0.0013
# Epoch 265/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.9911e-04 - val_loss: 0.0057
# Epoch 266/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.7966e-04 - val_loss: 6.1614e-04
# Epoch 267/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.8721e-04 - val_loss: 6.6104e-04
# Epoch 268/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.6955e-04 - val_loss: 0.0033
# Epoch 269/500
# 5/5 [==============================] - 1s 180ms/step - loss: 2.0976e-04 - val_loss: 0.0022
# Epoch 270/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.8467e-04 - val_loss: 7.0455e-04
# Epoch 271/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.5999e-04 - val_loss: 0.0078
# Epoch 272/500
# 5/5 [==============================] - 1s 178ms/step - loss: 4.2332e-04 - val_loss: 6.4901e-04
# Epoch 273/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.6719e-04 - val_loss: 0.0013
# Epoch 274/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.4621e-04 - val_loss: 0.0024
# Epoch 275/500
# 5/5 [==============================] - 1s 179ms/step - loss: 2.0154e-04 - val_loss: 0.0018
# Epoch 276/500
# 5/5 [==============================] - 1s 179ms/step - loss: 3.6628e-04 - val_loss: 9.2535e-04
# Epoch 277/500
# 5/5 [==============================] - 1s 178ms/step - loss: 4.2051e-04 - val_loss: 8.5193e-04
# Epoch 278/500
# 5/5 [==============================] - 1s 179ms/step - loss: 2
500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.4354e-04 - val_loss: 0.0041
# Epoch 374/500
# 5/5 [==============================] - 1s 177ms/step - loss: 2.0910e-04 - val_loss: 0.0015
# Epoch 375/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.6129e-04 - val_loss: 0.0016
# Epoch 376/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.5576e-04 - val_loss: 0.0010
# Epoch 377/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.4034e-04 - val_loss: 6.4444e-04
# Epoch 378/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.2985e-04 - val_loss: 6.8115e-04
# Epoch 379/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.6684e-04 - val_loss: 0.0024
# Epoch 380/500
# 5/5 [==============================] - 1s 176ms/step - loss: 1.6539e-04 - val_loss: 0.0013
# Epoch 381/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.6129e-04 - val_loss: 0.0175
# Epoch 382/500
# 5/5 [==============================] - 1s 177ms/step - loss: 5.7561e-04 - val_loss: 0.0109
# Epoch 383/500
# 5/5 [==============================] - 1s 181ms/step - loss: 7.7170e-04 - val_loss: 9.5335e-04
# Epoch 384/500
# 5/5 [==============================] - 1s 177ms/step - loss: 4.6893e-04 - val_loss: 0.0065
# Epoch 385/500
# 5/5 [==============================] - 1s 177ms/step - loss: 6.1632e-04 - val_loss: 9.7486e-04
# Epoch 386/500
# 5/5 [==============================] - 1s 179ms/step - loss: 2.0472e-04 - val_loss: 0.0021
# Epoch 387/500
# 5/5 [==============================] - 1s 181ms/step - loss: 1.9880e-04 - val_loss: 0.0031
# Epoch 388/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.5991e-04 - val_loss: 0.0065
# Epoch 389/500
# 5/5 [==============================] - 1s 176ms/step - loss: 3.4327e-04 - val_loss: 0.0028
# Epoch 390/500
# 5/5 [==============================] - 1s 177ms/step - loss: 2.4998e-04 - val_loss: 0.0026
# Epoch 391/500
# 5/5 [==============================] - 1s 177ms/step - loss: 2.0233e-04 - val_loss: 0.0015
# Epoch 392/500
# 5/5 [==============================] - 1s 181ms/step - loss: 1.7840e-04 - val_loss: 0.0020
# Epoch 393/500
# 5/5 [==============================] - 1s 176ms/step - loss: 1.5748e-04 - val_loss: 5.9134e-04
# Epoch 394/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.8661e-04 - val_loss: 0.0016
# Epoch 395/500
# 5/5 [==============================] - 1s 177ms/step - loss: 2.1517e-04 - val_loss: 0.0010
# Epoch 396/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.8569e-04 - val_loss: 6.2561e-04
# Epoch 397/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.6013e-04 - val_loss: 0.0020
# Epoch 398/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.2282e-04 - val_loss: 0.0014
# Epoch 399/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.8334e-04 - val_loss: 0.0024
# Epoch 400/500
# 5/5 [==============================] - 1s 180ms/step - loss: 2.6621e-04 - val_loss: 0.0021
# Epoch 401/500
# 5/5 [==============================] - 1s 180ms/step - loss: 2.4547e-04 - val_loss: 5.8063e-04
# Epoch 402/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.5717e-04 - val_loss: 0.0015
# Epoch 403/500
# 5/5 [==============================] - 1s 176ms/step - loss: 1.4838e-04 - val_loss: 0.0021
# Epoch 404/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.7046e-04 - val_loss: 0.0010
# Epoch 405/500
# 5/5 [==============================] - 1s 180ms/step - loss: 1.6695e-04 - val_loss: 0.0013
# Epoch 406/500
# 5/5 [==============================] - 1s 176ms/step - loss: 1.6918e-04 - val_loss: 0.0019
# Epoch 407/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.8825e-04 - val_loss: 0.0032
# Epoch 408/500
# 5/5 [==============================] - 1s 177ms/step - loss: 2.0678e-04 - val_loss: 5.8619e-04
# Epoch 409/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.7039e-04 - val_loss: 9.2665e-04
# Epoch 410/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.0616e-04 - val_loss: 0.0042
# Epoch 411/500
# 5/5 [==============================] - 1s 179ms/step - loss: 2.6743e-04 - val_loss: 0.0017
# Epoch 412/500
# 5/5 [==============================] - 1s 177ms/step - loss: 2.2761e-04 - val_loss: 0.0019
# Epoch 413/500
# 5/5 [==============================] - 1s 177ms/step - loss: 5.0086e-04 - val_loss: 0.0065
# Epoch 414/500
# 5/5 [==============================] - 1s 178ms/step - loss: 3.1377e-04 - val_loss: 0.0046
# Epoch 415/500
# 5/5 [==============================] - 1s 181ms/step - loss: 3.5908e-04 - val_loss: 0.0022
# Epoch 416/500
# 5/5 [==============================] - 1s 178ms/step - loss: 4.3553e-04 - val_loss: 0.0017
# Epoch 417/500
# 5/5 [==============================] - 1s 177ms/step - loss: 2.8614e-04 - val_loss: 0.0019
# Epoch 418/500
# 5/5 [==============================] - 1s 177ms/step - loss: 3.2922e-04 - val_loss: 0.0027
# Epoch 419/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.7235e-04 - val_loss: 0.0015
# Epoch 420/500
# 5/5 [==============================] - 1s 176ms/step - loss: 1.8943e-04 - val_loss: 6.4911e-04
# Epoch 421/500
# 5/5 [==============================] - 1s 175ms/step - loss: 1.4758e-04 - val_loss: 6.0455e-04
# Epoch 422/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.2572e-04 - val_loss: 6.0571e-04
# Epoch 423/500
# 5/5 [==============================] - 1s 180ms/step - loss: 1.3640e-04 - val_loss: 0.0017
# Epoch 424/500
# 5/5 [==============================] - 1s 181ms/step - loss: 1.6228e-04 - val_loss: 6.1715e-04
# Epoch 425/500
# 5/5 [==============================] - 1s 180ms/step - loss: 1.3767e-04 - val_loss: 7.5850e-04
# Epoch 426/500
# 5/5 [==============================] - 1s 180ms/step - loss: 1.4041e-04 - val_loss: 0.0012
# Epoch 427/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.4073e-04 - val_loss: 7.4405e-04
# Epoch 428/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.3886e-04 - val_loss: 9.1996e-04
# Epoch 429/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.4825e-04 - val_loss: 7.3813e-04
# Epoch 430/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.8842e-04 - val_loss: 0.0010
# Epoch 431/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.1392e-04 - val_loss: 0.0020
# Epoch 432/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.9566e-04 - val_loss: 7.3201e-04
# Epoch 433/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.8151e-04 - val_loss: 8.1294e-04
# Epoch 434/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.4672e-04 - val_loss: 7.0407e-04
# Epoch 435/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.4031e-04 - val_loss: 9.6949e-04
# Epoch 436/500
# 5/5 [==============================] - 1s 181ms/step - loss: 1.3524e-04 - val_loss: 8.1213e-04
# Epoch 437/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.5001e-04 - val_loss: 7.7803e-04
# Epoch 438/500
# 5/5 [==============================] - 1s 182ms/step - loss: 1.3618e-04 - val_loss: 6.5001e-04
# Epoch 439/500
# 5/5 [==============================] - 1s 182ms/step - loss: 1.4571e-04 - val_loss: 0.0010
# Epoch 440/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.4688e-04 - val_loss: 6.7928e-04
# Epoch 441/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.3621e-04 - val_loss: 0.0014
# Epoch 442/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.4035e-04 - val_loss: 0.0032
# Epoch 443/500
# 5/5 [==============================] - 1s 177ms/step - loss: 2.5776e-04 - val_loss: 0.0016
# Epoch 444/500
# 5/5 [==============================] - 1s 181ms/step - loss: 1.7536e-04 - val_loss: 0.0013
# Epoch 445/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.5479e-04 - val_loss: 0.0017
# Epoch 446/500
# 5/5 [==============================] - 1s 176ms/step - loss: 1.5224e-04 - val_loss: 7.4066e-04
# Epoch 447/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.2874e-04 - val_loss: 7.7603e-04
# Epoch 448/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.3496e-04 - val_loss: 8.4479e-04
# Epoch 449/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.3131e-04 - val_loss: 0.0011
# Epoch 450/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.3297e-04 - val_loss: 8.7217e-04
# Epoch 451/500
# 5/5 [==============================] - 1s 175ms/step - loss: 1.3624e-04 - val_loss: 0.0011
# Epoch 452/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.5679e-04 - val_loss: 0.0018
# Epoch 453/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.8326e-04 - val_loss: 8.5071e-04
# Epoch 454/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.4188e-04 - val_loss: 0.0011
# Epoch 455/500
# 5/5 [==============================] - 1s 177ms/step - loss: 2.8393e-04 - val_loss: 7.0977e-04
# Epoch 456/500
# 5/5 [==============================] - 1s 180ms/step - loss: 2.5588e-04 - val_loss: 9.8197e-04
# Epoch 457/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.2734e-04 - val_loss: 0.0055
# Epoch 458/500
# 5/5 [==============================] - 1s 176ms/step - loss: 2.5448e-04 - val_loss: 8.7456e-04
# Epoch 459/500
# 5/5 [==============================] - 1s 176ms/step - loss: 1.7412e-04 - val_loss: 7.3514e-04
# Epoch 460/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.5685e-04 - val_loss: 0.0016
# Epoch 461/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.5143e-04 - val_loss: 7.2392e-04
# Epoch 462/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.3082e-04 - val_loss: 7.2210e-04
# Epoch 463/500
# 5/5 [==============================] - 1s 176ms/step - loss: 1.2983e-04 - val_loss: 0.0012
# Epoch 464/500
# 5/5 [==============================] - 1s 180ms/step - loss: 1.2344e-04 - val_loss: 6.9396e-04
# Epoch 465/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.2947e-04 - val_loss: 0.0013
# Epoch 466/500
# 5/5 [==============================] - 1s 180ms/step - loss: 1.6133e-04 - val_loss: 0.0027
# Epoch 467/500
# 5/5 [==============================] - 1s 179ms/step - loss: 2.0012e-04 - val_loss: 8.9495e-04
# Epoch 468/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.5615e-04 - val_loss: 7.0000e-04
# Epoch 469/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.3870e-04 - val_loss: 6.6735e-04
# Epoch 470/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.3646e-04 - val_loss: 0.0010
# Epoch 471/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.4390e-04 - val_loss: 7.4420e-04
# Epoch 472/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.5527e-04 - val_loss: 0.0010
# Epoch 473/500
# 5/5 [==============================] - 1s 181ms/step - loss: 1.4322e-04 - val_loss: 9.6053e-04
# Epoch 474/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.3416e-04 - val_loss: 0.0029
# Epoch 475/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.7733e-04 - val_loss: 0.0011
# Epoch 476/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.5781e-04 - val_loss: 0.0012
# Epoch 477/500
# 5/5 [==============================] - 1s 180ms/step - loss: 1.5017e-04 - val_loss: 0.0020
# Epoch 478/500
# 5/5 [==============================] - 1s 181ms/step - loss: 1.5960e-04 - val_loss: 0.0066
# Epoch 479/500
# 5/5 [==============================] - 1s 178ms/step - loss: 3.4361e-04 - val_loss: 0.0041
# Epoch 480/500
# 5/5 [==============================] - 1s 180ms/step - loss: 2.7932e-04 - val_loss: 6.5460e-04
# Epoch 481/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.8046e-04 - val_loss: 0.0022
# Epoch 482/500
# 5/5 [==============================] - 1s 179ms/step - loss: 2.1130e-04 - val_loss: 7.7036e-04
# Epoch 483/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.6867e-04 - val_loss: 0.0020
# Epoch 484/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.1381e-04 - val_loss: 0.0012
# Epoch 485/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.7450e-04 - val_loss: 6.4853e-04
# Epoch 486/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.3577e-04 - val_loss: 0.0014
# Epoch 487/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.3786e-04 - val_loss: 7.6392e-04
# Epoch 488/500
# 5/5 [==============================] - 1s 180ms/step - loss: 1.1809e-04 - val_loss: 0.0010
# Epoch 489/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.1648e-04 - val_loss: 0.0020
# Epoch 490/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.4926e-04 - val_loss: 0.0032
# Epoch 491/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.8438e-04 - val_loss: 7.1778e-04
# Epoch 492/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.5065e-04 - val_loss: 6.7525e-04
# Epoch 493/500
# 5/5 [==============================] - 1s 178ms/step - loss: 1.3814e-04 - val_loss: 0.0017
# Epoch 494/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.3627e-04 - val_loss: 0.0019
# Epoch 495/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.4552e-04 - val_loss: 0.0015
# Epoch 496/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.5894e-04 - val_loss: 0.0048
# Epoch 497/500
# 5/5 [==============================] - 1s 178ms/step - loss: 2.9560e-04 - val_loss: 0.0011
# Epoch 498/500
# 5/5 [==============================] - 1s 176ms/step - loss: 2.2182e-04 - val_loss: 0.0011
# Epoch 499/500
# 5/5 [==============================] - 1s 177ms/step - loss: 1.8469e-04 - val_loss: 8.2674e-04
# Epoch 500/500
# 5/5 [==============================] - 1s 179ms/step - loss: 1.6463e-04 - val_loss: 0.0012

# %%
# model.evaluate(x_test, y_test)
model.evaluate(val_ds)
# Out:
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0012
# 0.001174934208393097

# %% [markdown]
# ## 6. 評估模型

# %%
l1, = plt.plot(history.history['loss'])
l2, = plt.plot(history.history['val_loss'])
plt.legend(handles=[l1,l2],labels=['loss','val_loss'],loc='best')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')

plt.show()

# %%
test_company = test_df[test_df["company"] == company_id]
test_company.head()
# Out:
#     company      date  price
# 77     2454  2021/2/1  905.0
# 76     2454  2021/2/2  931.0
# 75     2454  2021/2/3  950.0
# 74     2454  2021/2/4  946.0
# 73     2454  2021/2/5  950.0

# %% [markdown]
# ## 7. 做預測 (20分)

# %%
# 預測 Test data
# 現在我們取出了選定公司最後seq_len天
# 我們模型透過讀取seq_len天後預測出seq_len+1天的價格

# 將日期保存在datas中 (list)
# 將真實價格保存在real_prices中 (list)
# 將預測價格保存在pred_prices中 (list) *注: 請填入經過正規化後的價格

# input是一個經過**正規化**的真實價格list，請試著遍歷test_company來填滿上述三個list
# 可以參考TextGeneration的generateWords function，概念一樣，但是這次input請全部都填入"真實價格"
# 但是這次input請append "真實價格"
# 但是這次input請append "真實價格"
# 但是這次input請append "真實價格"
# 但是這次input請append "真實價格"
# 但是這次input請append "真實價格"

init_price = company.iloc[-seq_len:,:]["price"].values
dates = []
real_prices = []
pred_prices = []

input = scalar.transform(init_price)

# print(input)

for index,row in test_company.iterrows():
  # 我已經幫你把real_price和date放入list
  real_price = row["price"]
  real_prices.append(real_price)
  date = row["date"]
  dates.append(date)

  # 參考步驟 (在for迴圈中) :
  # 1. 把input轉**維度**成一個新變數next_input丟入model
  # 2. 獲得的pred取出seq中最後一個時間點的output數值 (提示: [0,-1,0])
  # 3. 把pred丟入pred_prices中
  # 4. 把real_price經過transform_one轉換成小數點並加在input後面
  # 5. 保持input長度為seq_len長 (也就是把最前面的數字踢掉)
  ##########
  # todo #
  ##########

  # 1. Expand the dimensions of input
  next_input = tf.expand_dims(input, axis=0)
  next_input = tf.expand_dims(next_input, axis=2)

  # 2. Get last output value from pred
  pred = model.predict(next_input)
  pred_last_output = pred[0, -1]

  # 3. Put the last pred output in to pred_prices
  pred_prices.append(pred_last_output[0])

  # 4. Put real_price which gone through transform_one in input
  real_price = scalar.transform_one(real_price)
  input.append(real_price)

  # 5. Keep input and seq_len with same length
  del(input[0])

# %%
print(f"dates : {dates[:10]}")
print(f"real_prices : {real_prices[:10]}")
print(f"pred_prices : {pred_prices[:10]}")
# Out:
# dates : ['2021/2/1', '2021/2/2', '2021/2/3', '2021/2/4', '2021/2/5', '2021/2/17', '2021/2/18', '2021/2/19', '2021/2/22', '2021/2/23']
# real_prices : [905.0, 931.0, 950.0, 946.0, 950.0, 980.0, 978.0, 964.0, 951.0, 965.0]
# pred_prices : [0.94651824, 0.97650605, 0.9971707, 1.0186511, 1.0163476, 1.0269876, 1.057229, 1.0560585, 1.0440573, 1.0351536]

# %% [markdown]
# * 預期結果:
#
# ![](https://i.imgur.com/iXdMWD6.png)

# %%
plt.figure(figsize=(16, 8))
l1, = plt.plot(dates,real_prices)
l2, = plt.plot(dates,scalar.recover(pred_prices))
plt.xticks(list(include_last_iter(0,len(dates),3)),rotation=30)
plt.legend(handles=[l1,l2],labels=['Real','Pred'],loc='best')
plt.title(companys[str(company_id)])
plt.xlabel("Date")
plt.ylabel("price")
plt.show()

# %% [markdown]
# * 預期成果
#
# 照理來說不會100%猜中，猜中幾乎100%可能是不小心偷看答案了。
#
# 不過要是你的模型正確的話，應該會看到如下pred price在true price附近而不是躺在地上。
#
# ![](https://i.imgur.com/tFoKEyK.png)
